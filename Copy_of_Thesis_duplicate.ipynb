# %% [markdown]
# <a href="https://colab.research.google.com/github/psingh-xyz/thesis/blob/main/Copy_of_Thesis_duplicate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clone the repository
# !git clone https://github.com/psingh-xyz/thesis
# Out:
# Cloning into 'thesis'...
# remote: Enumerating objects: 86, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 86 (delta 37), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (86/86), 15.27 MiB | 4.80 MiB/s, done.
# Resolving deltas: 100% (37/37), done.

# %%
# Run the Python script
# !python /content/thesis/common.py

# %% [markdown]
# # New Section

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.18.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 12.4 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.1 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->datasets) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, dill, multiprocess, datasets
# Successfully installed datasets-2.18.0 dill-0.3.8 multiprocess-0.70.16 xxhash-3.4.1

# %%
pip install sentencepiece
# Out:
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.1.99)

# %%
# !python /content/thesis/data_utils.py
# Out:
# Traceback (most recent call last):
#   File "/content/thesis/data_utils.py", line 16, in <module>
#     dataset = load_dataset("hyperpartisan_news_detection")
#   File "/usr/local/lib/python3.10/dist-packages/datasets/load.py", line 2556, in load_dataset
#     builder_instance = load_dataset_builder(
#   File "/usr/local/lib/python3.10/dist-packages/datasets/load.py", line 2265, in load_dataset_builder
#     builder_instance: DatasetBuilder = builder_cls(
#   File "/usr/local/lib/python3.10/dist-packages/datasets/builder.py", line 371, in __init__
#     self.config, self.config_id = self._create_builder_config(
#   File "/usr/local/lib/python3.10/dist-packages/datasets/builder.py", line 577, in _create_builder_config
#     raise ValueError(
# ValueError: Config name is missing.
# Please pick one among the available configs: ['byarticle', 'bypublisher']
# Example of usage:
# 	`load_dataset('hyperpartisan_news_detection', 'byarticle')`

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-2d5ca03cc039> in <cell line: 3>()
#       1 from datasets import load_dataset
#       2
# ----> 3 dataset = load_dataset("hyperpartisan_news_detection", byarticle)
#
# NameError: name 'byarticle' is not defined

# %%
# !python /content/thesis/step1.py  --dataset /content/thesis/Dataset/en_wiki/en_wiki.txt --prefix wiki_8k --tok-type unigram --vocab_size 8000
# Out:
# /content/thesis/Dataset/en_wiki/en_wiki.txt wiki_8k 8000
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=/content/thesis/Dataset/en_wiki/en_wiki.txt --model_prefix=wiki_8k  --vocab_size=8000         --pad_id=0 --unk_id=1 --bos_id=2 --eos_id=3 --model_type=unigram         --pad_piece=[PAD] --unk_piece=[UNK] --bos_piece=[BOS] --eos_piece=[EOS]         --user_defined_symbols=[CLS],[SEP],[MASK]
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: /content/thesis/Dataset/en_wiki/en_wiki.txt
#   input_format:
#   model_prefix: wiki_8k
#   model_type: UNIGRAM
#   vocab_size: 8000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   user_defined_symbols: [CLS]
#   user_defined_symbols: [SEP]
#   user_defined_symbols: [MASK]
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 1
#   bos_id: 2
#   eos_id: 3
#   pad_id: 0
#   unk_piece: [UNK]
#   bos_piece: [BOS]
#   eos_piece: [EOS]
#   pad_piece: [PAD]
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(351) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(183) LOG(INFO) Loading corpus: /content/thesis/Dataset/en_wiki/en_wiki.txt
# trainer_interface.cc(407) LOG(INFO) Loaded all 38346 sentences
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: [PAD]
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: [UNK]
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: [BOS]
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: [EOS]
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: [CLS]
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: [SEP]
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: [MASK]
# trainer_interface.cc(428) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(537) LOG(INFO) all chars count=10847749
# trainer_interface.cc(548) LOG(INFO) Done: 99.95% characters are covered.
# trainer_interface.cc(558) LOG(INFO) Alphabet size=99
# trainer_interface.cc(559) LOG(INFO) Final character coverage=0.9995
# trainer_interface.cc(591) LOG(INFO) Done! preprocessed 38346 sentences.
# unigram_model_trainer.cc(222) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(226) LOG(INFO) Extracting frequent sub strings... node_num=5279072
# unigram_model_trainer.cc(274) LOG(INFO) Initialized 150281 seed sentencepieces
# trainer_interface.cc(597) LOG(INFO) Tokenizing input sentences with whitespace: 38346
# trainer_interface.cc(608) LOG(INFO) Done! 99169
# unigram_model_trainer.cc(564) LOG(INFO) Using 99169 sentences for EM training
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=64834 obj=11.4432 num_tokens=208720 num_tokens/piece=3.2193
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=53028 obj=9.40575 num_tokens=210604 num_tokens/piece=3.97156
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=39754 obj=9.36411 num_tokens=220349 num_tokens/piece=5.54281
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=39695 obj=9.33667 num_tokens=220703 num_tokens/piece=5.55997
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=29770 obj=9.39914 num_tokens=238064 num_tokens/piece=7.99678
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=29769 obj=9.37944 num_tokens=238052 num_tokens/piece=7.99664
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=22326 obj=9.46921 num_tokens=256980 num_tokens/piece=11.5103
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=22326 obj=9.44521 num_tokens=256942 num_tokens/piece=11.5086
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=16744 obj=9.57728 num_tokens=276892 num_tokens/piece=16.5368
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=16744 obj=9.54648 num_tokens=276859 num_tokens/piece=16.5348
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=12558 obj=9.71558 num_tokens=296274 num_tokens/piece=23.5925
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=12558 obj=9.67727 num_tokens=296221 num_tokens/piece=23.5882
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=9418 obj=9.89207 num_tokens=315892 num_tokens/piece=33.5413
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=9418 obj=9.84638 num_tokens=315847 num_tokens/piece=33.5365
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=8800 obj=9.89531 num_tokens=320382 num_tokens/piece=36.407
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=8800 obj=9.88486 num_tokens=320377 num_tokens/piece=36.4065
# trainer_interface.cc(686) LOG(INFO) Saving model: wiki_8k.model
# trainer_interface.cc(698) LOG(INFO) Saving vocabs: wiki_8k.vocab

# %%
# !python /content/thesis/step1.py  --dataset /content/thesis/Dataset/medical_text/train.dat --prefix medical_8k --tok-type unigram --vocab_size 8000
# Out:
# /content/thesis/Dataset/medical_text/train.dat medical_8k 8000
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=/content/thesis/Dataset/medical_text/train.dat --model_prefix=medical_8k  --vocab_size=8000         --pad_id=0 --unk_id=1 --bos_id=2 --eos_id=3 --model_type=unigram         --pad_piece=[PAD] --unk_piece=[UNK] --bos_piece=[BOS] --eos_piece=[EOS]         --user_defined_symbols=[CLS],[SEP],[MASK]
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: /content/thesis/Dataset/medical_text/train.dat
#   input_format:
#   model_prefix: medical_8k
#   model_type: UNIGRAM
#   vocab_size: 8000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   user_defined_symbols: [CLS]
#   user_defined_symbols: [SEP]
#   user_defined_symbols: [MASK]
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 1
#   bos_id: 2
#   eos_id: 3
#   pad_id: 0
#   unk_piece: [UNK]
#   bos_piece: [BOS]
#   eos_piece: [EOS]
#   pad_piece: [PAD]
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(351) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(183) LOG(INFO) Loading corpus: /content/thesis/Dataset/medical_text/train.dat
# trainer_interface.cc(407) LOG(INFO) Loaded all 14438 sentences
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: [PAD]
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: [UNK]
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: [BOS]
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: [EOS]
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: [CLS]
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: [SEP]
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: [MASK]
# trainer_interface.cc(428) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(537) LOG(INFO) all chars count=17797245
# trainer_interface.cc(548) LOG(INFO) Done: 99.9575% characters are covered.
# trainer_interface.cc(558) LOG(INFO) Alphabet size=71
# trainer_interface.cc(559) LOG(INFO) Final character coverage=0.999575
# trainer_interface.cc(591) LOG(INFO) Done! preprocessed 14438 sentences.
# unigram_model_trainer.cc(222) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(226) LOG(INFO) Extracting frequent sub strings... node_num=11018606
# unigram_model_trainer.cc(274) LOG(INFO) Initialized 151281 seed sentencepieces
# trainer_interface.cc(597) LOG(INFO) Tokenizing input sentences with whitespace: 14438
# trainer_interface.cc(608) LOG(INFO) Done! 107064
# unigram_model_trainer.cc(564) LOG(INFO) Using 107064 sentences for EM training
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=58034 obj=11.6816 num_tokens=241393 num_tokens/piece=4.15951
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=47943 obj=9.06433 num_tokens=242132 num_tokens/piece=5.05041
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=35950 obj=9.04832 num_tokens=253782 num_tokens/piece=7.0593
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=35929 obj=9.03311 num_tokens=254625 num_tokens/piece=7.08689
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=26946 obj=9.10939 num_tokens=274989 num_tokens/piece=10.2052
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=26945 obj=9.0923 num_tokens=274932 num_tokens/piece=10.2035
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=20207 obj=9.21692 num_tokens=299154 num_tokens/piece=14.8045
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=20206 obj=9.19448 num_tokens=299117 num_tokens/piece=14.8034
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=15154 obj=9.376 num_tokens=326709 num_tokens/piece=21.5593
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=15154 obj=9.34342 num_tokens=326697 num_tokens/piece=21.5585
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=11365 obj=9.58529 num_tokens=356166 num_tokens/piece=31.3388
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=11365 obj=9.54462 num_tokens=356180 num_tokens/piece=31.3401
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=8800 obj=9.81214 num_tokens=382596 num_tokens/piece=43.4768
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=8800 obj=9.76874 num_tokens=382644 num_tokens/piece=43.4823
# trainer_interface.cc(686) LOG(INFO) Saving model: medical_8k.model
# trainer_interface.cc(698) LOG(INFO) Saving vocabs: medical_8k.vocab

# %%
# !python /content/thesis/step1.py  --dataset /content/thesis/Dataset/ohsumed.txt --prefix ohsumed_8k --tok-type unigram --vocab_size 8000
# Out:
# /content/thesis/Dataset/ohsumed.txt ohsumed_8k 8000
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=/content/thesis/Dataset/ohsumed.txt --model_prefix=ohsumed_8k  --vocab_size=8000         --pad_id=0 --unk_id=1 --bos_id=2 --eos_id=3 --model_type=unigram         --pad_piece=[PAD] --unk_piece=[UNK] --bos_piece=[BOS] --eos_piece=[EOS]         --user_defined_symbols=[CLS],[SEP],[MASK]
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: /content/thesis/Dataset/ohsumed.txt
#   input_format:
#   model_prefix: ohsumed_8k
#   model_type: UNIGRAM
#   vocab_size: 8000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   user_defined_symbols: [CLS]
#   user_defined_symbols: [SEP]
#   user_defined_symbols: [MASK]
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 1
#   bos_id: 2
#   eos_id: 3
#   pad_id: 0
#   unk_piece: [UNK]
#   bos_piece: [BOS]
#   eos_piece: [EOS]
#   pad_piece: [PAD]
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(351) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(183) LOG(INFO) Loading corpus: /content/thesis/Dataset/ohsumed.txt
# trainer_interface.cc(407) LOG(INFO) Loaded all 7400 sentences
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: [PAD]
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: [UNK]
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: [BOS]
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: [EOS]
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: [CLS]
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: [SEP]
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: [MASK]
# trainer_interface.cc(428) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(537) LOG(INFO) all chars count=9371709
# trainer_interface.cc(548) LOG(INFO) Done: 99.9585% characters are covered.
# trainer_interface.cc(558) LOG(INFO) Alphabet size=72
# trainer_interface.cc(559) LOG(INFO) Final character coverage=0.999585
# trainer_interface.cc(591) LOG(INFO) Done! preprocessed 7400 sentences.
# unigram_model_trainer.cc(222) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(226) LOG(INFO) Extracting frequent sub strings... node_num=4910481
# unigram_model_trainer.cc(274) LOG(INFO) Initialized 132759 seed sentencepieces
# trainer_interface.cc(597) LOG(INFO) Tokenizing input sentences with whitespace: 7400
# trainer_interface.cc(608) LOG(INFO) Done! 91067
# unigram_model_trainer.cc(564) LOG(INFO) Using 91067 sentences for EM training
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=48956 obj=11.8641 num_tokens=206036 num_tokens/piece=4.2086
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=41436 obj=9.27693 num_tokens=206713 num_tokens/piece=4.98873
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=31068 obj=9.27316 num_tokens=217946 num_tokens/piece=7.01513
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=31044 obj=9.25318 num_tokens=218062 num_tokens/piece=7.02429
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=23280 obj=9.35959 num_tokens=235906 num_tokens/piece=10.1334
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=23278 obj=9.33583 num_tokens=235876 num_tokens/piece=10.133
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=17457 obj=9.50122 num_tokens=256715 num_tokens/piece=14.7056
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=17457 obj=9.46824 num_tokens=256705 num_tokens/piece=14.705
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=13092 obj=9.69346 num_tokens=279909 num_tokens/piece=21.3802
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=13092 obj=9.652 num_tokens=279925 num_tokens/piece=21.3814
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=9819 obj=9.94586 num_tokens=304410 num_tokens/piece=31.0021
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=9819 obj=9.89541 num_tokens=304394 num_tokens/piece=31.0005
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=8800 obj=10.0126 num_tokens=313741 num_tokens/piece=35.6524
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=8800 obj=9.99356 num_tokens=313784 num_tokens/piece=35.6573
# trainer_interface.cc(686) LOG(INFO) Saving model: ohsumed_8k.model
# trainer_interface.cc(698) LOG(INFO) Saving vocabs: ohsumed_8k.vocab

# %%
# !python /content/thesis/step2.py
# Out:
# 100% 38460/38460 [00:03<00:00, 11247.32it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:429: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# /content/models/rawBert_rawTokenizer/ /content/models/rawBert_rawTokenizer/Bert_Wiki_8k/
#   0% 0/603 [00:00<?, ?it/s]We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See https://huggingface.co/docs/transformers/troubleshooting#incorrect-output-when-padding-tokens-arent-masked.
# 100% 603/603 [20:40<00:00,  2.06s/it]

# %%
from datasets import load_dataset

dataset = load_dataset("ohsumed")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading data:   0%|          | 0.00/32.2M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/181M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/54709 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/293855 [00:00<?, ? examples/s]

# %%
dataset.to_txt("/content/thesis/Dataset/ohsumed")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-ef3531b30415> in <cell line: 1>()
# ----> 1 dataset.to_txt("/content/thesis/Dataset/ohsumed")
#
# AttributeError: 'DatasetDict' object has no attribute 'to_txt'

# %%
# Save the dataset to your local machine
dataset.save("/content/thesis/Dataset")
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/54709 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/293855 [00:00<?, ? examples/s]

# %%
from datasets import load_dataset

# Load the dataset
dataset = load_dataset("ohsumed")

# Accessing a specific split of the dataset (e.g., train split)
split = dataset['train']

# Accessing a specific column of the dataset (e.g., text column)
texts = split['abstract']

# Saving the text column to a TXT file
with open("/content/thesis/Dataset/texts.txt", "w") as file:
    for text in texts:
        file.write(text + "\n")

# %%
# !python /content/thesis/step3.py

# %%
custom_model = BertForSequenceClassification.from_pretrained(
    pretrained_model_path,
   # num_labels=num_labels  # Set this parameter if using a custom number of labels
)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at /content/models/rawBert_rawTokenizer/Bert_Wiki_8k/ and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from transformers import BertForSequenceClassification

# Load the pre-trained model
pretrained_model_path = "/content/models/rawBert_rawTokenizer/Bert_Wiki_8k/"
pretrained_model = BertForSequenceClassification.from_pretrained(pretrained_model_path)

# Your custom model creation code
custom_model = BertForSequenceClassification.from_pretrained(pretrained_model_path)

# Manually assign the weights from the pre-trained model to the custom model
custom_model.bert.load_state_dict(pretrained_model.bert.state_dict())

# Save the custom model
custom_model.save_pretrained("content/custom_model/")
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at /content/models/rawBert_rawTokenizer/Bert_Wiki_8k/ and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at /content/models/rawBert_rawTokenizer/Bert_Wiki_8k/ and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# !python /content/thesis/Step4.py
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at /content/models/rawBert_rawTokenizer/Bert_Wiki_8k/ and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at /content/models/rawBert_rawTokenizer/Bert_Wiki_8k/ and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at /content/models/rawBert_rawTokenizer/Bert_Wiki_8k/ and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at /content/models/rawBert_rawTokenizer/Bert_Wiki_8k/ and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at /content/models/rawBert_rawTokenizer/Bert_Wiki_8k/ and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at /content/models/rawBert_rawTokenizer/Bert_Wiki_8k/ and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# !python /content/thesis/step5.py --dataset_name quora
# Out:
# Some weights of BertForMaskedLM were not initialized from the model checkpoint at /content/models/matched_models/wiki_medical_8k/avg and are newly initialized: ['cls.predictions.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# model load /content/models/matched_models/wiki_medical_8k/avg
# SentencePiece size 8000 /content/medical_8k.model
# Traceback (most recent call last):
#   File "/content/thesis/step5.py", line 105, in <module>
#     main()
#   File "/content/thesis/step5.py", line 62, in main
#     dataset = DATASETS[args.dataset_name](f'{args.dataset_prefix}/{args.dataset_name}', sp)
#   File "/content/thesis/data_utils.py", line 200, in __init__
#     df = pd.read_csv(f'{path}/train.csv')
#   File "/usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py", line 331, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py", line 950, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py", line 605, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py", line 1442, in __init__
#     self._engine = self._make_engine(f, self.engine)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py", line 1735, in _make_engine
#     self.handles = get_handle(
#   File "/usr/local/lib/python3.10/dist-packages/pandas/io/common.py", line 856, in get_handle
#     handle = open(
# FileNotFoundError: [Errno 2] No such file or directory: '/thesis/datasets/quora/train.csv'
